# %% [markdown]
# ## Exercise

# %% [markdown]
# For this exercise, you will be working with the [House Price Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code).
#
# Please grab the train.csv file from Kaggle and explore this dataset. You need to perform explroatory data analysis and see if there is any correlation between the variables and analyze the distribution of the dataset. The question is open-ended and basically you're asked to perform EDA.

# %% [markdown]
# 1- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 3 of your assignment, you need to submit at least one jupyter notebook file and one pdf file.
#
#
# 2- Push your code and project to github and provide the link to your code here. Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %%
import pandas as pd

# To load the data into a pandas DataFrame
data = pd.read_csv('train.csv')

# To print the first few rows to see what the data looks like
print(data.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# To check the correlation between variables
print(data.corr())
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# Find the highest correlation values
highest_corr = corr_matrix.abs().unstack().sort_values(ascending=False)

# Exclude self-correlation and duplicate values
highest_corr = highest_corr[(highest_corr != 1) & (highest_corr != 0)].drop_duplicates()

# Print the top 10 highest correlation values
print(highest_corr[:10])
# Out:
# Fare      Pclass      0.549500
# SibSp     Parch       0.414838
# Pclass    Age         0.369226
# Survived  Pclass      0.338481
# SibSp     Age         0.308247
# Fare      Survived    0.257307
#           Parch       0.216225
# Age       Parch       0.189119
# SibSp     Fare        0.159651
# Fare      Age         0.096067
# dtype: float64

# %%
# To get summary statistics for the numerical variables
print(data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# To create a scatter plot to visualize the correlation between Fare and Pclass
import matplotlib.pyplot as plt
plt.scatter(data['Fare'], data['Pclass'])
plt.xlabel('Fare')
plt.ylabel('Pclass')
plt.show()

# %%
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# To create a histogram to visualize the distribution of a variable
plt.hist(data['Fare'], bins=20)
plt.xlabel('Fare')
plt.ylabel('Pclass')
plt.show()

# %%
plt.hist(data['Pclass'], bins=20)
plt.xlabel('Fare')
plt.ylabel('Pclass')
plt.show()

# %%
# To create a scatter plot to visualize the correlation between SibSp and Parch
import matplotlib.pyplot as plt
plt.scatter(data['SibSp'], data['Parch'])
plt.xlabel('SibSp')
plt.ylabel('Parch')
plt.show()

# %%
plt.hist(data['SibSp'], bins=20)
plt.xlabel('SibSp')
plt.ylabel('Parch')
plt.show()
